# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # **Hyperparameter Optimization for Keras with Scikit-Learn**

# %% [markdown]
# Estimated time needed: **35** minutes

# %% [markdown]
# We already know how to use `RandomizedSearchCV` and `GridSearchCV` for hyperparameter tuning in machine learning models - linear regression,  decision trees, and so on. It turns out that we can utilize the same functionality easily for neural networks! Keras offers a scikit-learn wrapper that lets us perform randomized/grid search on its models using the same syntax (example `fit()`, `.best_score_`). In this lab, we will take a look at how to do so for a Sequential model.
#
# As a reminder, both search types may take a long time to run for this lab.

# %% [markdown]
# ## **Table of Contents**
#
# <ol>
#     <li><a href="https://#Objectives">Objectives</a></li>
#     <li>
#         <a href="https://#Setup">Setup</a>
#         <ol>
#             <li><a href="https://#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="https://#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="https://#Defining-Helper-Functions">Defining Helper Functions</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Create-the-Model">Create the Model</a>
#         <ol>
#             <li><a href="https://#Load-the-Data">Load the Data</a></li>
#             <li><a href="https://#Data-Wrangling">Data Wrangling</a></li>
#             <li><a href="https://#Build-the-Base-Model">Build the Base Model</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Randomized-Search">Randomized Search</a>
#         <ol>
#             <li><a href="https://#Parameters">Parameters</a></li>
#             <li><a href="https://#Define-and-Fit-RandomizedSearchCV">Define and Fit RandomizedSearchCV</a></li>
#             <li><a href="https://#Performance-Evaluation">Performance Evaluation</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Exercised">Exercises</a>
#         <ol>
#             <li><a href="https://#Exercise-1:-Build-the-Base-Model">Exercise 1: Build the Base Model</a></li>
#             <li><a href="https://#Exercise-2:-Define-Search-Parameters">Exercise 2: Define Search Parameters</a></li>
#             <li><a href="https://#Exercise-3:-Fit-RandomizedSearchCV">Exercise 3: Fit RandomizedSearchCV</a></li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Use Keras' scikit-learn wrapper to utilize sklearn functions on Keras models
# *   Apply randomized search on Keras models to find the best hyperparameters

# %% [markdown]
# ***

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and machine-learning-pipeline related functions.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for additional plotting tools.
# *   [`tensorflow`](https://www.tensorflow.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and neural network related functions.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run this notebook command in a different Jupyter environment (like Watson Studio or Anaconda), you will need to install these libraries by removing the `#` sign before `!mamba` in the following code cell.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy numpy==1.21.4 matplotlib==3.5.0 scikit-learn==0.20.1
# Note: If your environment doesn't support "!mamba install", use "!pip install"

# %% [markdown]
# The following required libraries are **not** pre-installed in the Skills Network Labs environment. **You will need to run the following cell** to install them:

# %%
#!mamba install -qy tqdm

# %%
# Upgrade to newest version of skillsnetwork for more functionalities
# Restart kernel after doing so
# !pip install --upgrade skillsnetwork
# Out:
# Requirement already satisfied: skillsnetwork in c:\github\ibm_machine_learning\venv\lib\site-packages (0.21.9)
# Requirement already satisfied: ipython in c:\github\ibm_machine_learning\venv\lib\site-packages (from skillsnetwork) (8.26.0)
# Requirement already satisfied: ipywidgets<9,>=8 in c:\github\ibm_machine_learning\venv\lib\site-packages (from skillsnetwork) (8.1.3)
# Requirement already satisfied: requests<3,>=2 in c:\github\ibm_machine_learning\venv\lib\site-packages (from skillsnetwork) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4 in c:\github\ibm_machine_learning\venv\lib\site-packages (from skillsnetwork) (4.66.5)
# Requirement already satisfied: comm>=0.1.3 in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipywidgets<9,>=8->skillsnetwork) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipywidgets<9,>=8->skillsnetwork) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipywidgets<9,>=8->skillsnetwork) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipywidgets<9,>=8->skillsnetwork) (3.0.11)
# Requirement already satisfied: decorator in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipython->skillsnetwork) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipython->skillsnetwork) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipython->skillsnetwork) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipython->skillsnetwork) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipython->skillsnetwork) (2.18.0)
# Requirement already satisfied: stack-data in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipython->skillsnetwork) (0.6.3)
# Requirement already satisfied: colorama in c:\github\ibm_machine_learning\venv\lib\site-packages (from ipython->skillsnetwork) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\github\ibm_machine_learning\venv\lib\site-packages (from requests<3,>=2->skillsnetwork) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\github\ibm_machine_learning\venv\lib\site-packages (from requests<3,>=2->skillsnetwork) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\github\ibm_machine_learning\venv\lib\site-packages (from requests<3,>=2->skillsnetwork) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\github\ibm_machine_learning\venv\lib\site-packages (from requests<3,>=2->skillsnetwork) (2024.7.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\github\ibm_machine_learning\venv\lib\site-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.4)
# Requirement already satisfied: wcwidth in c:\github\ibm_machine_learning\venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->skillsnetwork) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\github\ibm_machine_learning\venv\lib\site-packages (from stack-data->ipython->skillsnetwork) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\github\ibm_machine_learning\venv\lib\site-packages (from stack-data->ipython->skillsnetwork) (2.4.1)
# Requirement already satisfied: pure-eval in c:\github\ibm_machine_learning\venv\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\github\ibm_machine_learning\venv\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython->skillsnetwork) (1.16.0)

# %% [markdown]
# ### Importing Required Libraries

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # tensorflow INFO and WARNING messages are not printed
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

from tqdm import tqdm
import numpy as np
# %matplotlib inline

import tensorflow as tf
import keras
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from scikeras.wrappers import KerasClassifier

import skillsnetwork

# %% [markdown]
# ### Defining Helper Functions

# %%
# Vectorize integer sequence
def vectorize_sequence(sequence, dimensions):
    results = np.zeros((len(sequence), dimensions))
    for index,value in enumerate(sequence):
        if max(value) < dimensions:
            results[index, value] = 1
    return results

# Convert label into one-hot format
def one_hot_label(labels, dimensions):
    results = np.zeros((len(labels), dimensions))
    for index,value in enumerate(labels):
        if value < dimensions:
            results[index, value] = 1
    return results

# %% [markdown]
# ## Create the Model

# %% [markdown]
# ### Load the Data

# %% [markdown]
# For this exercise, we will be using the [Reuters newswire classification dataset](https://keras.io/api/datasets/reuters/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera35714171-2022-01-01) from Keras. The training features for this dataset are lists of word indices (integers), corresponding to their frequency in the dataset. The response labels take on one of 46 classes, representing the newswire's topic.

# %%
dict1 = np.load("reuters.npz", allow_pickle=True)
X = dict1['x']
y = dict1['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# To get the word for a specific index, we can also extract a dictionary of words to index using the following Keras function.

# %%
word_to_ind = tf.keras.datasets.reuters.get_word_index(path="reuters_word_index.json")

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# Since each observation is a list of words that appear in the newswire, the length varies. Hence, we will vectorize the dataset using `vectorize_sequence()` to ensure that all inputs to our model have the same dimension. Labels are also one-hot encoded with `one_hot_label()` because classes (news topic) are not ordinal.

# %%
dim_x = max([max(sequence) for sequence in X_train])+1
dim_y = max(y_train)+1

X_train_vec = vectorize_sequence(X_train, dim_x)
X_test_vec = vectorize_sequence(X_test, dim_x)
y_train_hot = one_hot_label(y_train, dim_y)
y_test_hot = one_hot_label(y_test, dim_y)

# %% [markdown]
# ### Build the Base Model

# %% [markdown]
# In order to apply `RandomizedSearchCV` on Keras models, we will be using `KerasClassifier` from `keras.wrappers.scikit_learn` library, which will let us apply scikit-learn functions on the model.

# %% [markdown]
# We define `create_model()` below to detail which layers we want to include in the model. Recall that the final Dense layer has 46 units to correspond to the number of classes. This also prompts us to use categorical cross entropy as a loss function. Here, `neuron` is included as a parameter with default value because we want to tune it later.

# %%
# Create Keras Sequential Model as base model
def create_model(neurons = 10):
    model = Sequential()
    model.add(Dense(neurons, activation='linear'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(46, activation='softmax'))
    model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# For the base model, we won't change any parameters so that we can compare them with results after hyperparameter tuning. We also specify some of the default values for hyperparameters that don't appear in `create_model()` (example batch_size, epochs) such that they are defined when applying randomized search.

# %%
np.random.seed(0)
base_model = KerasClassifier(build_fn=create_model, verbose=0, batch_size=10, epochs=1)

# %% [markdown]
# Fitting the model on the train set, we obtain the test score for our base model.

# %%
# Get pre-tuned results
base_model.fit(X_train_vec, y_train_hot)
base_score = base_model.score(X_test_vec, y_test_hot)
print("The baseline accuracy is: %.3f" % base_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Get pre-tuned results
# ----> 2 base_model.fit(X_train_vec, y_train_hot)
#       3 base_score = base_model.score(X_test_vec, y_test_hot)
#       4 print("The baseline accuracy is: %.3f" % base_score)
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\scikeras\wrappers.py:1501, in KerasClassifier.fit(self, X, y, sample_weight, **kwargs)
#    1499     sample_weight = 1 if sample_weight is None else sample_weight
#    1500     sample_weight *= compute_sample_weight(class_weight=self.class_weight, y=y)
# -> 1501 super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#    1502 return self
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\scikeras\wrappers.py:770, in BaseWrapper.fit(self, X, y, sample_weight, **kwargs)
#     765 kwargs["epochs"] = kwargs.get(
#     766     "epochs", getattr(self, "fit__epochs", self.epochs)
#     767 )
#     768 kwargs["initial_epoch"] = kwargs.get("initial_epoch", 0)
# --> 770 self._fit(
#     771     X=X,
#     772     y=y,
#     773     sample_weight=sample_weight,
#     774     warm_start=self.warm_start,
#     775     **kwargs,
#     776 )
#     778 return self
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\scikeras\wrappers.py:936, in BaseWrapper._fit(self, X, y, sample_weight, warm_start, epochs, initial_epoch, **kwargs)
#     933 y = self.target_encoder_.transform(y)
#     934 X = self.feature_encoder_.transform(X)
# --> 936 self._check_model_compatibility(y)
#     938 self._fit_keras_model(
#     939     X,
#     940     y,
#    (...)
#     945     **kwargs,
#     946 )
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\scikeras\wrappers.py:559, in BaseWrapper._check_model_compatibility(self, y)
#     554 # check if this is a multi-output model
#     555 if getattr(self, "n_outputs_expected_", None):
#     556     # n_outputs_expected_ is generated by data transformers
#     557     # we recognize the attribute but do not force it to be
#     558     # generated
# --> 559     if self.n_outputs_expected_ != len(self.model_.outputs):
#     560         raise ValueError(
#     561             "Detected a Keras model input of size"
#     562             f" {self.n_outputs_expected_ }, but {self.model_} has"
#     563             f" {len(self.model_.outputs)} outputs"
#     564         )
#     565 # check that if the user gave us a loss function it ended up in
#     566 # the actual model
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\keras\src\models\sequential.py:295, in Sequential.outputs(self)
#     293 if self._functional:
#     294     return self._functional.outputs
# --> 295 raise ValueError(
#     296     f"Sequential model '{self.name}' has no defined outputs yet."
#     297 )
#
# ValueError: Sequential model 'sequential_1' has no defined outputs yet.

# %% [markdown]
# ## Randomized Search

# %% [markdown]
# ### Parameters

# %% [markdown]
# As you might already know from performing randomized search on machine learning models, we have to create a dictionary for the hyperparameter values. Let's start by defining the values we want to experiment with! Note that if you would like to test other parameters, they must be defined in the base model as well.

# %%
batch_size = [10, 20, 60, 80]
epochs = [1, 3, 5]
neurons = [1, 10, 20, 30]

params = {'batch_size': batch_size, 'epochs': epochs, 'neurons': neurons}
params
# Out:
# {'batch_size': [10, 20, 60, 80],
#  'epochs': [1, 3, 5],
#  'neurons': [1, 10, 20, 30]}

# %% [markdown]
# ### Define and Fit RandomizedSearchCV

# %%
search = RandomizedSearchCV(estimator=base_model, param_distributions=params, cv=3)

# %% [markdown]
# Now, fit randomized search on `X_train_vec` and `y_train_hot` as you would for any other model. **Note that this may take a while to run (10+ minutes)**, especially if there are a lot of parameter combinations, or if the epoch size is big. If you have the resources, you could also switch out `RandomizedSearchCV` for `GridSearchCV` to search over every combination of hyperparameters (takes even more time to run).

# %%
search_result = search.fit(X_train_vec, y_train_hot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 search_result = search.fit(X_train_vec, y_train_hot)
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\sklearn\model_selection\_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
#    1020 # multimetric is determined here because in the case of a callable
#    1021 # self.scoring the return type is only known after calling
#    1022 first_test_score = all_out[0]["test_scores"]
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\sklearn\model_selection\_search.py:1959, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1957 def _run_search(self, evaluate_candidates):
#    1958     """Search n_iter candidates from param_distributions"""
# -> 1959     evaluate_candidates(
#    1960         ParameterSampler(
#    1961             self.param_distributions, self.n_iter, random_state=self.random_state
#    1962         )
#    1963     )
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\sklearn\model_selection\_search.py:964, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     956 if self.verbose > 0:
#     957     print(
#     958         "Fitting {0} folds for each of {1} candidates,"
#     959         " totalling {2} fits".format(
#     960             n_splits, n_candidates, n_candidates * n_splits
#     961         )
#     962     )
# --> 964 out = parallel(
#     965     delayed(_fit_and_score)(
#     966         clone(base_estimator),
#     967         X,
#     968         y,
#     969         train=train,
#     970         test=test,
#     971         parameters=parameters,
#     972         split_progress=(split_idx, n_splits),
#     973         candidate_progress=(cand_idx, n_candidates),
#     974         **fit_and_score_kwargs,
#     975     )
#     976     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     977         enumerate(candidate_params),
#     978         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     979     )
#     980 )
#     982 if len(out) < 1:
#     983     raise ValueError(
#     984         "No fits were performed. "
#     985         "Was the CV iterator empty? "
#     986         "Were there no candidates?"
#     987     )
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\sklearn\model_selection\_validation.py:876, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     869 score_params_test = _check_method_params(X, params=score_params, indices=test)
#     871 if parameters is not None:
#     872     # here we clone the parameters, since sometimes the parameters
#     873     # themselves might be estimators, e.g. when we search over different
#     874     # estimators in a pipeline.
#     875     # ref: https://github.com/scikit-learn/scikit-learn/pull/26786
# --> 876     estimator = estimator.set_params(**clone(parameters, safe=False))
#     878 start_time = time.time()
#     880 X_train, y_train = _safe_split(estimator, X, y, train)
#
# File c:\GitHub\IBM_Machine_Learning\venv\Lib\site-packages\scikeras\wrappers.py:1175, in BaseWrapper.set_params(self, **params)
#    1171             super().set_params(**{param: value})
#    1172         except ValueError:
#    1173             # Give a SciKeras specific user message to aid
#    1174             # in moving from the Keras wrappers
# -> 1175             raise ValueError(
#    1176                 f"Invalid parameter {param} for estimator {self.__name__}."
#    1177                 "\nThis issue can likely be resolved by setting this parameter"
#    1178                 f" in the {self.__name__} constructor:"
#    1179                 f"\n`{self.__name__}({param}={value})`"
#    1180                 "\nCheck the list of available parameters with"
#    1181                 " `estimator.get_params().keys()`"
#    1182             ) from None
#    1183 return self
#
# ValueError: Invalid parameter neurons for estimator KerasClassifier.
# This issue can likely be resolved by setting this parameter in the KerasClassifier constructor:
# `KerasClassifier(neurons=10)`
# Check the list of available parameters with `estimator.get_params().keys()`

# %% [markdown]
# ### Performance Evaluation

# %% [markdown]
# Let's take a look at the results from this search! In particular, we will examine the mean and standard deviation of the cross-validation score under different hyperparameter combinations.

# %%
means = search_result.cv_results_['mean_test_score']
stds = search_result.cv_results_['std_test_score']
params = search_result.cv_results_['params']

# %% [markdown]
# `RandomizedSearchCV` also has attributes for us to access the best score and parameters directly.

# %%
print("Best mean cross-validated score: {} using {}".format(round(search_result.best_score_,3), search_result.best_params_))

# %% [markdown]
# We can also print out all the other scores:

# %%
for mean, stdev, param in zip(means, stds, params):
    print("Mean cross-validated score: {} ({}) using: {}".format(round(mean,3), round(stdev,3), param))

# %% [markdown]
# From this, we can see how different the other models' scores are compared to the optimal model's performance. Some are pretty close to the best score, whereas there are combinations that yield much lower scores.Thank goodness we didn't pick those! With randomized search on neural networks, we are able to determine the best values in an automated way.

# %% [markdown]
# Using the best estimator, let's get the test score:

# %%
print("Best test score: %.3f" % search_result.best_estimator_.score(X_test_vec, y_test_hot))

# %% [markdown]
# Our test score has increased compared to the base model!

# %% [markdown]
# ## Exercises

# %% [markdown]
# Now, let's try Randomized search on other hyperparameters!

# %% [markdown]
# ### Exercise 1: Build the Base Model

# %% [markdown]
# This time, we want to look at different optimizers, learning rates, and dropout rates. Since the learning rate is a value fed into `optimizer`, the parameter has to be named a certain way in `create_model()` and `params`: `optimizer__learning_rate`.

# %%
# Create Keras Sequential Model as base model
def create_model(optimizer = 'RMSprop', optimizer__learning_rate = 0.1, dropout_rate = 0.2):
    model = Sequential()
    model.add(Dense(64, activation='linear'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(46, activation='softmax'))
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# TODO: Create `base_model` using `KerasClassifier`. Fit it to the training set and obtain the test score

# %% [markdown]
# <details>
#     <summary>Click here for sample solution</summary>
#
# ```python
#
# np.random.seed(0)
# base_model = KerasClassifier(build_fn=create_model, verbose=0, batch_size=100, epochs=1)
# base_model.fit(X_train_vec, y_train_hot)
# base_score = base_model.score(X_test_vec, y_test_hot)
# print("The baseline accuracy is: {}".format(base_score))
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2: Define Search Parameters

# %% [markdown]
# Now, we will specify which values we want to experiment with and put them into a dictionary.

# %%
# TODO: specify 3-4 values for each of the following parameters

# TODO: convert it into a dictionary variable named `params`

# %% [markdown]
# <details>
#     <summary>Click here for sample solution</summary>
#
# ```python
#
# optimizer = ['SGD','RMSprop','Adam']
# learning_rate = [0.01, 0.1, 1]
# dropout_rate = [0.1, 0.3, 0.6, 0.9]
# params = dict(optimizer=optimizer, optimizer__learning_rate=learning_rate, dropout_rate = dropout_rate)
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3: Fit RandomizedSearchCV **(Note that this may take a while to run (5+ minutes))**

# %%
# TODO: Create `RandomizedSearchCV` object `search` and fit it to the train set

# %% [markdown]
# <details>
#     <summary>Click here for solution</summary>
#
# ```python
#
# search = RandomizedSearchCV(estimator=base_model, param_distributions=params, cv=3)
# search_result = search.fit(X_train_vec, y_train_hot)
#
# ```
#
# </details>

# %%
# TODO: Obtain the best cross-validation score and test scores

# %% [markdown]
# <details>
#     <summary>Click here for solution</summary>
#
# ```python
#
# print("Best mean cross-validated score: {} using {}".format(round(search_result.best_score_,3), search_result.best_params_))
# print("Best test score: %.3f" % search_result.best_estimator_.score(X_test_vec, y_test_hot))
#
# ```
#
# </details>

# %% [markdown]
# ## Authors

# %% [markdown]
# [Cindy Huang](https://www.linkedin.com/in/cindy-shih-ting-huang/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera35714171-2022-01-01) is a data science associate of the Skills Network team. She has a passion for machine learning to improve user experience, especially in the area of computational linguistics.

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Contributor with Link](contributor_linl), Contributor No Link

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description |
# | ----------------- | ------- | ---------- | ------------------ |
# | 2022-07-20        | 1.0     | Cindy H.   | Create lab draft   |
# | 2022-09-01        | 1.0     | Steve Hord | QA pass edits      |
# | 2022-11-11        | 1.0     | Shengkai C.| Review and edit    |

# %% [markdown]
# Copyright © 2022 IBM Corporation. All rights reserved.
